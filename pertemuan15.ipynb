# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np 

df = pd.read_csv("supermarket_sales.csv")
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity       Date   Time  \
# 0         Health and beauty       74.69         7   1/5/2019  13:08
# 1    Electronic accessories       15.28         5   3/8/2019  10:29
# 2        Home and lifestyle       46.33         7   3/3/2019  13:23
# 3         Health and beauty       58.22         8  1/27/2019  20:33
# 4         Sports and travel       86.31         7   2/8/2019  10:37
# ..                      ...         ...       ...        ...    ...
# 995       Health and beauty       40.35         1  1/29/2019  13:46
# 996      Home and lifestyle       97.38        10   3/2/2019  17:16
# 997      Food and beverages       31.84         1   2/9/2019  13:22
# 998      Home and lifestyle       65.82         1  2/22/2019  15:33
# 999     Fashion accessories       88.34         7  2/18/2019  13:28
#
#          Payment  Rating
# 0        Ewallet     9.1
# 1           Cash     9.6
# 2    Credit card     7.4
# 3        Ewallet     8.4
# 4        Ewallet     5.3
# ..           ...     ...
# 995      Ewallet     6.2
# 996      Ewallet     4.4
# 997         Cash     7.7
# 998         Cash     4.1
# 999         Cash     6.6
#
# [1000 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Invoice ID     1000 non-null   object
#  1   Branch         1000 non-null   object
#  2   City           1000 non-null   object
#  3   Customer type  1000 non-null   object
#  4   Gender         1000 non-null   object
#  5   Product line   1000 non-null   object
#  6   Unit price     1000 non-null   float64
#  7   Quantity       1000 non-null   int64
#  8   Date           1000 non-null   object
#  9   Time           1000 non-null   object
#  10  Payment        1000 non-null   object
#  11  Rating         1000 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 93.9+ KB

# %%
unique_product = df["Product line"].unique()

# %%
df["Branch"] = df["Branch"].replace(["A", "B", "C"], [1,2,3])
df["City"] = df["City"].replace(["Yangon", "Naypyitaw", "Mandalay"], [1,2,3])
df["Customer type"] = df["Customer type"].replace(["Normal", "Member"], [1,2])
df["Product line"] = df["Product line"].replace(unique_product, [4,1,5,6,3,2])
df["Payment"] = df["Payment"].replace(["Cash", "Credit card", "Ewallet"], [1,2,3])

df
# Out:
# /var/folders/q2/2h4p204s56d3vhv_jx5hmc6m0000gn/T/ipykernel_1475/591340624.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Branch"] = df["Branch"].replace(["A", "B", "C"], [1,2,3])
# /var/folders/q2/2h4p204s56d3vhv_jx5hmc6m0000gn/T/ipykernel_1475/591340624.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["City"] = df["City"].replace(["Yangon", "Naypyitaw", "Mandalay"], [1,2,3])
# /var/folders/q2/2h4p204s56d3vhv_jx5hmc6m0000gn/T/ipykernel_1475/591340624.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Customer type"] = df["Customer type"].replace(["Normal", "Member"], [1,2])
# /var/folders/q2/2h4p204s56d3vhv_jx5hmc6m0000gn/T/ipykernel_1475/591340624.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Product line"] = df["Product line"].replace(unique_product, [4,1,5,6,3,2])
# /var/folders/q2/2h4p204s56d3vhv_jx5hmc6m0000gn/T/ipykernel_1475/591340624.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Payment"] = df["Payment"].replace(["Cash", "Credit card", "Ewallet"], [1,2,3])
#       Invoice ID  Branch  City  Customer type  Gender  Product line  \
# 0    750-67-8428       1     1              2  Female             4
# 1    226-31-3081       3     2              1  Female             1
# 2    631-41-3108       1     1              1    Male             5
# 3    123-19-1176       1     1              2    Male             4
# 4    373-73-7910       1     1              1    Male             6
# ..           ...     ...   ...            ...     ...           ...
# 995  233-67-5758       3     2              1    Male             4
# 996  303-96-2227       2     3              1  Female             5
# 997  727-02-1313       1     1              2    Male             3
# 998  347-56-2442       1     1              1    Male             5
# 999  849-09-3807       1     1              2  Female             2
#
#      Unit price  Quantity       Date   Time  Payment  Rating
# 0         74.69         7   1/5/2019  13:08        3     9.1
# 1         15.28         5   3/8/2019  10:29        1     9.6
# 2         46.33         7   3/3/2019  13:23        2     7.4
# 3         58.22         8  1/27/2019  20:33        3     8.4
# 4         86.31         7   2/8/2019  10:37        3     5.3
# ..          ...       ...        ...    ...      ...     ...
# 995       40.35         1  1/29/2019  13:46        3     6.2
# 996       97.38        10   3/2/2019  17:16        3     4.4
# 997       31.84         1   2/9/2019  13:22        1     7.7
# 998       65.82         1  2/22/2019  15:33        1     4.1
# 999       88.34         7  2/18/2019  13:28        1     6.6
#
# [1000 rows x 12 columns]

# %%
df["Total"] = df["Unit price"] * df["Quantity"]
df["Tax"] = df["Total"] * 0.05
df["Final price"] = df["Total"] - df["Tax"]

df
# Out:
#       Invoice ID  Branch  City  Customer type  Gender  Product line  \
# 0    750-67-8428       1     1              2  Female             4
# 1    226-31-3081       3     2              1  Female             1
# 2    631-41-3108       1     1              1    Male             5
# 3    123-19-1176       1     1              2    Male             4
# 4    373-73-7910       1     1              1    Male             6
# ..           ...     ...   ...            ...     ...           ...
# 995  233-67-5758       3     2              1    Male             4
# 996  303-96-2227       2     3              1  Female             5
# 997  727-02-1313       1     1              2    Male             3
# 998  347-56-2442       1     1              1    Male             5
# 999  849-09-3807       1     1              2  Female             2
#
#      Unit price  Quantity       Date   Time  Payment  Rating   Total      Tax  \
# 0         74.69         7   1/5/2019  13:08        3     9.1  522.83  26.1415
# 1         15.28         5   3/8/2019  10:29        1     9.6   76.40   3.8200
# 2         46.33         7   3/3/2019  13:23        2     7.4  324.31  16.2155
# 3         58.22         8  1/27/2019  20:33        3     8.4  465.76  23.2880
# 4         86.31         7   2/8/2019  10:37        3     5.3  604.17  30.2085
# ..          ...       ...        ...    ...      ...     ...     ...      ...
# 995       40.35         1  1/29/2019  13:46        3     6.2   40.35   2.0175
# 996       97.38        10   3/2/2019  17:16        3     4.4  973.80  48.6900
# 997       31.84         1   2/9/2019  13:22        1     7.7   31.84   1.5920
# 998       65.82         1  2/22/2019  15:33        1     4.1   65.82   3.2910
# 999       88.34         7  2/18/2019  13:28        1     6.6  618.38  30.9190
#
#      Final price
# 0       496.6885
# 1        72.5800
# 2       308.0945
# 3       442.4720
# 4       573.9615
# ..           ...
# 995      38.3325
# 996     925.1100
# 997      30.2480
# 998      62.5290
# 999     587.4610
#
# [1000 rows x 15 columns]

# %%
group_a = df.groupby("Product line")["Quantity"].sum()

sns.barplot(x = group_a.index, y = group_a.values, label = "Quantity")
plt.legend()
plt.show()

# %%
data_normal = df.loc[df["Customer type"] == 1]
data_member = df.loc[df["Customer type"] == 2]

test = df[df["Customer type"].isin([1,2])]

group_normal = data_normal.groupby("Product line")["Customer type"].count()
group_member = data_member.groupby("Product line")["Customer type"].count()

x = np.arange(len(group_normal.index))
width = 0.4

plt.bar(x - width/2, group_normal.values, width = width, label = "Normal")
plt.bar(x + width/2, group_member.values, width = width, label = "Member")

plt.title('Normal and Member by Product')
plt.xlabel('Category')
plt.xticks(x, group_normal.index)  
plt.legend()
plt.show()

# %%
test
# Out:
#       Invoice ID  Branch  City  Customer type  Gender  Product line  \
# 0    750-67-8428       1     1              2  Female             4
# 1    226-31-3081       3     2              1  Female             1
# 2    631-41-3108       1     1              1    Male             5
# 3    123-19-1176       1     1              2    Male             4
# 4    373-73-7910       1     1              1    Male             6
# ..           ...     ...   ...            ...     ...           ...
# 995  233-67-5758       3     2              1    Male             4
# 996  303-96-2227       2     3              1  Female             5
# 997  727-02-1313       1     1              2    Male             3
# 998  347-56-2442       1     1              1    Male             5
# 999  849-09-3807       1     1              2  Female             2
#
#      Unit price  Quantity       Date   Time  Payment  Rating   Total      Tax  \
# 0         74.69         7   1/5/2019  13:08        3     9.1  522.83  26.1415
# 1         15.28         5   3/8/2019  10:29        1     9.6   76.40   3.8200
# 2         46.33         7   3/3/2019  13:23        2     7.4  324.31  16.2155
# 3         58.22         8  1/27/2019  20:33        3     8.4  465.76  23.2880
# 4         86.31         7   2/8/2019  10:37        3     5.3  604.17  30.2085
# ..          ...       ...        ...    ...      ...     ...     ...      ...
# 995       40.35         1  1/29/2019  13:46        3     6.2   40.35   2.0175
# 996       97.38        10   3/2/2019  17:16        3     4.4  973.80  48.6900
# 997       31.84         1   2/9/2019  13:22        1     7.7   31.84   1.5920
# 998       65.82         1  2/22/2019  15:33        1     4.1   65.82   3.2910
# 999       88.34         7  2/18/2019  13:28        1     6.6  618.38  30.9190
#
#      Final price
# 0       496.6885
# 1        72.5800
# 2       308.0945
# 3       442.4720
# 4       573.9615
# ..           ...
# 995      38.3325
# 996     925.1100
# 997      30.2480
# 998      62.5290
# 999     587.4610
#
# [1000 rows x 15 columns]

# %%
group_c = df.groupby("Payment")["Invoice ID"].count()

sns.barplot(x = group_c.index, y = group_c.values, label = "Invoice ID")
plt.legend()
plt.show()

# %%
group_d = df.groupby("Payment")["Product line"].count()

plt.pie(group_d.values, labels = group_d.index, autopct="%1.1f%%")

plt.ylabel("Product line")
plt.legend()
plt.show()

# %%
group_e = df.groupby("Product line")["Final price"].sum()

sns.barplot(x = group_e.index, y = group_e.values, label = "Final price")
plt.legend()
plt.show()
